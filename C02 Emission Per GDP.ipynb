# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
df = pd.read_excel(r"E:\5 Python\Final co2 emission file.xlsx")
df
# Out:
#            country  year  population          gdp  coal_co2  gas_co2  oil_co2  \
# 0      Afghanistan  1850     3752993            0     0.000      0.0    0.000
# 1      Afghanistan  1851     3767956            0     0.000      0.0    0.000
# 2      Afghanistan  1852     3783940            0     0.000      0.0    0.000
# 3      Afghanistan  1853     3800954            0     0.000      0.0    0.000
# 4      Afghanistan  1854     3818038            0     0.000      0.0    0.000
# ...            ...   ...         ...          ...       ...      ...      ...
# 43945     Zimbabwe  2019    15271377  25146417152     6.013      0.0    3.778
# 43946     Zimbabwe  2020    15526888  23178706944     4.935      0.0    3.063
# 43947     Zimbabwe  2021    15797220  25140088832     5.938      0.0    3.735
# 43948     Zimbabwe  2022    16069061  25901586432     6.516      0.0    3.379
# 43949     Zimbabwe  2023    16340829            0     7.271      0.0    3.362
#
#        cement_co2  flaring_co2  land_use_change_co2  ...  \
# 0           0.000          0.0                2.993  ...
# 1           0.000          0.0                3.015  ...
# 2           0.000          0.0                3.035  ...
# 3           0.000          0.0                3.052  ...
# 4           0.000          0.0                3.067  ...
# ...           ...          ...                  ...  ...
# 43945       0.473          0.0                9.544  ...
# 43946       0.496          0.0                8.936  ...
# 43947       0.531          0.0                8.549  ...
# 43948       0.531          0.0                8.022  ...
# 43949       0.531          0.0                7.403  ...
#
#        share_global_cumulative_other_co2  share_global_cumulative_co2  \
# 0                                    0.0                        0.000
# 1                                    0.0                        0.000
# 2                                    0.0                        0.000
# 3                                    0.0                        0.000
# 4                                    0.0                        0.000
# ...                                  ...                          ...
# 43945                                0.0                        0.047
# 43946                                0.0                        0.046
# 43947                                0.0                        0.046
# 43948                                0.0                        0.045
# 43949                                0.0                        0.045
#
#        temperature_change_from_co2  consumption_co2  \
# 0                            0.000            0.000
# 1                            0.000            0.000
# 2                            0.000            0.000
# 3                            0.000            0.000
# 4                            0.000            0.000
# ...                            ...              ...
# 43945                        0.001           10.236
# 43946                        0.001            9.107
# 43947                        0.001           10.742
# 43948                        0.001           10.740
# 43949                        0.001            0.000
#
#        consumption_co2_per_capita  consumption_co2_per_gdp  \
# 0                           0.000                    0.000
# 1                           0.000                    0.000
# 2                           0.000                    0.000
# 3                           0.000                    0.000
# 4                           0.000                    0.000
# ...                           ...                      ...
# 43945                       0.670                    0.407
# 43946                       0.587                    0.393
# 43947                       0.680                    0.427
# 43948                       0.668                    0.415
# 43949                       0.000                    0.000
#
#        primary_energy_consumption  trade_co2  trade_co2_share  \
# 0                           0.000      0.000            0.000
# 1                           0.000      0.000            0.000
# 2                           0.000      0.000            0.000
# 3                           0.000      0.000            0.000
# 4                           0.000      0.000            0.000
# ...                           ...        ...              ...
# 43945                      46.120     -0.027           -0.261
# 43946                      41.997      0.612            7.209
# 43947                      42.145      0.539            5.280
# 43948                       0.000      0.315            3.018
# 43949                       0.000      0.000            0.000
#
#                           region
# 0      South_and_South_East_Asia
# 1      South_and_South_East_Asia
# 2      South_and_South_East_Asia
# 3      South_and_South_East_Asia
# 4      South_and_South_East_Asia
# ...                          ...
# 43945         Sub_Saharan_Africa
# 43946         Sub_Saharan_Africa
# 43947         Sub_Saharan_Africa
# 43948         Sub_Saharan_Africa
# 43949         Sub_Saharan_Africa
#
# [43950 rows x 69 columns]

# %%
duplicate_rows = df[df.duplicated()].sum()
duplicate_rows
# Out:
# country                         0
# year                            0
# population                      0
# gdp                             0
# coal_co2                      0.0
#                              ...
# consumption_co2_per_gdp       0.0
# primary_energy_consumption    0.0
# trade_co2                     0.0
# trade_co2_share               0.0
# region                          0
# Length: 69, dtype: object

# %%
df.isna().sum()
# Out:
# country                       0
# year                          0
# population                    0
# gdp                           0
# coal_co2                      0
#                              ..
# consumption_co2_per_gdp       0
# primary_energy_consumption    0
# trade_co2                     0
# trade_co2_share               0
# region                        0
# Length: 69, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

le=LabelEncoder()

for i in df.select_dtypes(include='object'):

    df[i]=le.fit_transform(df[i])
df
# Out:
#        country  year  population          gdp  coal_co2  gas_co2  oil_co2  \
# 0            0  1850     3752993            0     0.000      0.0    0.000
# 1            0  1851     3767956            0     0.000      0.0    0.000
# 2            0  1852     3783940            0     0.000      0.0    0.000
# 3            0  1853     3800954            0     0.000      0.0    0.000
# 4            0  1854     3818038            0     0.000      0.0    0.000
# ...        ...   ...         ...          ...       ...      ...      ...
# 43945      254  2019    15271377  25146417152     6.013      0.0    3.778
# 43946      254  2020    15526888  23178706944     4.935      0.0    3.063
# 43947      254  2021    15797220  25140088832     5.938      0.0    3.735
# 43948      254  2022    16069061  25901586432     6.516      0.0    3.379
# 43949      254  2023    16340829            0     7.271      0.0    3.362
#
#        cement_co2  flaring_co2  land_use_change_co2  ...  \
# 0           0.000          0.0                2.993  ...
# 1           0.000          0.0                3.015  ...
# 2           0.000          0.0                3.035  ...
# 3           0.000          0.0                3.052  ...
# 4           0.000          0.0                3.067  ...
# ...           ...          ...                  ...  ...
# 43945       0.473          0.0                9.544  ...
# 43946       0.496          0.0                8.936  ...
# 43947       0.531          0.0                8.549  ...
# 43948       0.531          0.0                8.022  ...
# 43949       0.531          0.0                7.403  ...
#
#        share_global_cumulative_other_co2  share_global_cumulative_co2  \
# 0                                    0.0                        0.000
# 1                                    0.0                        0.000
# 2                                    0.0                        0.000
# 3                                    0.0                        0.000
# 4                                    0.0                        0.000
# ...                                  ...                          ...
# 43945                                0.0                        0.047
# 43946                                0.0                        0.046
# 43947                                0.0                        0.046
# 43948                                0.0                        0.045
# 43949                                0.0                        0.045
#
#        temperature_change_from_co2  consumption_co2  \
# 0                            0.000            0.000
# 1                            0.000            0.000
# 2                            0.000            0.000
# 3                            0.000            0.000
# 4                            0.000            0.000
# ...                            ...              ...
# 43945                        0.001           10.236
# 43946                        0.001            9.107
# 43947                        0.001           10.742
# 43948                        0.001           10.740
# 43949                        0.001            0.000
#
#        consumption_co2_per_capita  consumption_co2_per_gdp  \
# 0                           0.000                    0.000
# 1                           0.000                    0.000
# 2                           0.000                    0.000
# 3                           0.000                    0.000
# 4                           0.000                    0.000
# ...                           ...                      ...
# 43945                       0.670                    0.407
# 43946                       0.587                    0.393
# 43947                       0.680                    0.427
# 43948                       0.668                    0.415
# 43949                       0.000                    0.000
#
#        primary_energy_consumption  trade_co2  trade_co2_share  region
# 0                           0.000      0.000            0.000       5
# 1                           0.000      0.000            0.000       5
# 2                           0.000      0.000            0.000       5
# 3                           0.000      0.000            0.000       5
# 4                           0.000      0.000            0.000       5
# ...                           ...        ...              ...     ...
# 43945                      46.120     -0.027           -0.261       6
# 43946                      41.997      0.612            7.209       6
# 43947                      42.145      0.539            5.280       6
# 43948                       0.000      0.315            3.018       6
# 43949                       0.000      0.000            0.000       6
#
# [43950 rows x 69 columns]

# %%
df.columns
# Out:
# Index(['country', 'year', 'population', 'gdp', 'coal_co2', 'gas_co2',
#        'oil_co2', 'cement_co2', 'flaring_co2', 'land_use_change_co2',
#        'other_industry_co2', 'co2', 'total_co2_emission_including_luc',
#        'co2_including_luc_per_unit_energy', 'energy_co2',
#        'co2_per_unit_energy', 'coal_co2_per_capita', 'gas_co2_per_capita',
#        'oil_co2_per_capita', 'cement_co2_per_capita', 'flaring_co2_per_capita',
#        'land_use_change_co2_per_capita', 'other_co2_per_capita',
#        'co2_per_capita', 'co2_per_capita_including_luc', 'energy_per_capita',
#        'co2_per_gdp', 'co2_including_luc_per_gdp', 'energy_per_gdp',
#        'cumulative_coal_co2', 'cumulative_gas_co2', 'cumulative_oil_co2',
#        'cumulative_cement_co2', 'cumulative_flaring_co2', 'cumulative_luc_co2',
#        'cumulative_other_co2', 'cumulative_co2_including_luc',
#        'cumulative_co2', 'total_cumulative_co2', 'co2_growth_abs',
#        'co2_growth_prct', 'co2_including_luc_growth_abs',
#        'co2_including_luc_growth_prct', 'share_global_coal_co2',
#        'share_global_gas_co2', 'share_global_oil_co2',
#        'share_global_cement_co2', 'share_global_flaring_co2',
#        'share_global_co2_including_luc', 'share_global_luc_co2',
#        'share_global_other_co2', 'share_global_co2',
#        'share_global_cumulative_coal_co2', 'share_global_cumulative_gas_co2',
#        'share_global_cumulative_oil_co2', 'share_global_cumulative_cement_co2',
#        'share_global_cumulative_flaring_co2',
#        'share_global_cumulative_luc_co2',
#        'share_global_cumulative_co2_including_luc',
#        'share_global_cumulative_other_co2', 'share_global_cumulative_co2',
#        'temperature_change_from_co2', 'consumption_co2',
#        'consumption_co2_per_capita', 'consumption_co2_per_gdp',
#        'primary_energy_consumption', 'trade_co2', 'trade_co2_share', 'region'],
#       dtype='object')

# %%
#saparate data into x(input or independent variable) and y(output or dependent variable)
x=df.drop(['co2_per_gdp'], axis=1)
y=df.co2_per_gdp

# %%
# Split data into train and text
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.2,random_state=42)

# %%
from sklearn.ensemble import ExtraTreesRegressor
from sklearn.datasets import make_regression

# %%
# Initialize and train ExtraTreesRegressor
model = ExtraTreesRegressor(n_estimators=100, random_state=42)
# Train the model
model.fit(x_train, y_train)
# Out:
# ExtraTreesRegressor(random_state=42)

# %%
# Make predictions on the test set
y_pred = model.predict(x_test)

# %%
df2=pd.DataFrame({'y_test':y_test,'y_pred':y_pred})
df2
# Out:
#        y_test   y_pred
# 28093   0.000  0.00000
# 29555   0.000  0.00597
# 19635   0.401  0.40204
# 1331    0.000  0.00000
# 43765   0.083  0.08651
# ...       ...      ...
# 918     0.000  0.00000
# 11296   0.168  0.18709
# 23890   0.069  0.07095
# 10646   0.295  0.29893
# 26988   0.125  0.11758
#
# [8790 rows x 2 columns]

# %%
from sklearn.metrics import r2_score,mean_squared_error

# %%
# Evaluate the model's performance
mse = mean_squared_error(y_test, y_pred)  # Mean Squared Error
rmse = mse**0.5  # Root Mean Squared Error
r2 = r2_score(y_test, y_pred)  # R-squared score

# %%
# Print evaluation metrics
print(f"Mean Squared Error (MSE): {mse}")
print(f"Root Mean Squared Error (RMSE): {rmse}")
print(f"R-squared (R2): {r2}")
# Out:
# Mean Squared Error (MSE): 0.00047589015924914634
# Root Mean Squared Error (RMSE): 0.021814906812754126
# R-squared (R2): 0.9956369643517583

# %%
# Sort the features and their importances in descending order
sorted_features = sorted(zip(x.columns, feature_importances), key=lambda x: x[1], reverse=True)

print("\nFeature Importances (Descending Order):")
for feature, importance in sorted_features:
    print(f"{feature}: {importance}")
# Out:
# Feature Importances (Descending Order):
# co2_per_unit_energy: 0.40541426598651087
# consumption_co2_per_gdp: 0.08889804173971161
# co2_including_luc_per_gdp: 0.07995533552827642
# energy_per_gdp: 0.06582641497252424
# coal_co2_per_capita: 0.03598673755945723
# share_global_coal_co2: 0.020664686091635662
# co2_per_capita_including_luc: 0.01864662648616393
# co2_per_capita: 0.015876704475653036
# share_global_co2: 0.01490297570256405
# share_global_cumulative_flaring_co2: 0.01434668878206842
# co2_including_luc_per_unit_energy: 0.01377467551440597
# share_global_cumulative_co2_including_luc: 0.012595692390654317
# share_global_co2_including_luc: 0.011652784359958928
# share_global_cumulative_oil_co2: 0.010950866421981618
# gas_co2_per_capita: 0.009771960333494818
# share_global_oil_co2: 0.00945763917284616
# cement_co2_per_capita: 0.009273622377279788
# share_global_cumulative_co2: 0.008288798186925022
# region: 0.008237828721303006
# cumulative_co2_including_luc: 0.008095012903018034
# share_global_cement_co2: 0.007931104728493262
# flaring_co2_per_capita: 0.007898806766447924
# share_global_cumulative_coal_co2: 0.007452164033519143
# land_use_change_co2: 0.006949856535238901
# temperature_change_from_co2: 0.0062886493232003704
# trade_co2_share: 0.006002451535621773
# oil_co2_per_capita: 0.005987308939049997
# coal_co2: 0.005981342011493893
# population: 0.0058118867639003315
# year: 0.005258761753179035
# gdp: 0.005003197357279928
# cumulative_oil_co2: 0.004762486132369599
# co2_growth_abs: 0.004633789585144146
# cumulative_coal_co2: 0.004527604361457072
# oil_co2: 0.004322795914508427
# share_global_cumulative_luc_co2: 0.00365464980562267
# cumulative_co2: 0.003411616914991039
# country: 0.003320514390811142
# energy_per_capita: 0.0032080488442455895
# consumption_co2_per_capita: 0.0031532790475900995
# co2: 0.0030515500250096624
# share_global_cumulative_gas_co2: 0.0026946327988696273
# cumulative_luc_co2: 0.0026438374684117816
# total_co2_emission_including_luc: 0.0025582035427377608
# cumulative_cement_co2: 0.002204090021812243
# land_use_change_co2_per_capita: 0.0021655614069543876
# total_cumulative_co2: 0.0019955813626382495
# share_global_gas_co2: 0.001903727155197218
# share_global_cumulative_cement_co2: 0.0017533008384161867
# share_global_luc_co2: 0.0017401103143073915
# share_global_flaring_co2: 0.0014732773102279146
# energy_co2: 0.0013144163745435926
# flaring_co2: 0.0010790168390319382
# gas_co2: 0.001068471842950587
# cement_co2: 0.0008434257478346036
# cumulative_gas_co2: 0.0007382910165634364
# cumulative_flaring_co2: 0.00043572964733645217
# other_co2_per_capita: 0.0003848283307896541
# primary_energy_consumption: 0.0002233664062859524
# co2_growth_prct: 0.00021481390310332807
# co2_including_luc_growth_prct: 0.00020986697026418623
# other_industry_co2: 0.00020568434780178128
# share_global_cumulative_other_co2: 0.000183710206498356
# cumulative_other_co2: 0.00017697255016209886
# share_global_other_co2: 0.0001649660898425575
# co2_including_luc_growth_abs: 0.0001374903836288071
# consumption_co2: 0.00013707493819073067
# trade_co2: 0.0001203297099922456

# %%
# Sort the features and their importances in descending order
sorted_features = sorted(zip(x.columns, feature_importances), key=lambda x: x[1], reverse=True)

# Extract the top 20 features
top_20_features = sorted_features[:20]
features, importances = zip(*top_20_features)

# Create a bar plot
plt.figure(figsize=(12, 8))  # Adjusted size for 20 features
colors = sns.color_palette("viridis", len(features))  # Generate colors for the bars

# Plot each bar individually with its specific color
for i, (feature, importance) in enumerate(zip(features, importances)):
    plt.barh(feature, importance, color=colors[i])

plt.title("Top 20 Feature Importances")
plt.xlabel("Importance")
plt.ylabel("Feature")
plt.gca().invert_yaxis()  # Invert the y-axis to show the highest importance at the top
plt.tight_layout()
plt.show()
